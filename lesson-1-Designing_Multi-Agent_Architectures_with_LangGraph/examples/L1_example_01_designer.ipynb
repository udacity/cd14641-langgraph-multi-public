# %%
from maa import AgentArchitectureDesigner

# %%
designer = AgentArchitectureDesigner()

# %%
g1 = designer.render(designer.build("pipeline", 3))

# %%
g2 = designer.render(designer.build("network", 3))

# %%
g3 = designer.render(designer.build("supervisor", 3))

# %%
g4 = designer.render(designer.build("hierarchical", 5))
